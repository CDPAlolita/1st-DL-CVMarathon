# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# C:\Users\4D212\Anaconda3\envs\dlm\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Users\4D212\Anaconda3\envs\dlm\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\4D212\Anaconda3\envs\dlm\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\4D212\Anaconda3\envs\dlm\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\4D212\Anaconda3\envs\dlm\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\4D212\Anaconda3\envs\dlm\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\4D212\Anaconda3\envs\dlm\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0062 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00211, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0017 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00211 to 0.00191, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00191 to 0.00188, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00188 to 0.00184, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0011 - val_loss: 0.0017
#
# Epoch 00005: val_loss improved from 0.00184 to 0.00172, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.1528e-04 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00172 to 0.00167, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 7.8697e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00167 to 0.00155, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 7.0257e-04 - val_loss: 0.0014
#
# Epoch 00008: val_loss improved from 0.00155 to 0.00142, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 6.3145e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00142 to 0.00131, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 5.6916e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00131 to 0.00120, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 5.2389e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00120 to 0.00115, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 4.8527e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00115 to 0.00110, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 4.4589e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00110 to 0.00107, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 4.2103e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss improved from 0.00107 to 0.00104, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 4.1009e-04 - val_loss: 9.7544e-04
#
# Epoch 00015: val_loss improved from 0.00104 to 0.00098, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.8103e-04 - val_loss: 9.3229e-04
#
# Epoch 00016: val_loss improved from 0.00098 to 0.00093, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.5094e-04 - val_loss: 9.2031e-04
#
# Epoch 00017: val_loss improved from 0.00093 to 0.00092, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.4547e-04 - val_loss: 9.0908e-04
#
# Epoch 00018: val_loss improved from 0.00092 to 0.00091, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.3418e-04 - val_loss: 9.0451e-04
#
# Epoch 00019: val_loss improved from 0.00091 to 0.00090, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.0659e-04 - val_loss: 9.1398e-04
#
# Epoch 00020: val_loss did not improve from 0.00090
# Epoch 21/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.1096e-04 - val_loss: 8.6070e-04
#
# Epoch 00021: val_loss improved from 0.00090 to 0.00086, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.9716e-04 - val_loss: 8.7904e-04
#
# Epoch 00022: val_loss did not improve from 0.00086
# Epoch 23/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.9089e-04 - val_loss: 8.5321e-04
#
# Epoch 00023: val_loss improved from 0.00086 to 0.00085, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.7788e-04 - val_loss: 8.5865e-04
#
# Epoch 00024: val_loss did not improve from 0.00085
# Epoch 25/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.7161e-04 - val_loss: 8.5537e-04
#
# Epoch 00025: val_loss did not improve from 0.00085
# Epoch 26/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.7159e-04 - val_loss: 8.6383e-04
#
# Epoch 00026: val_loss did not improve from 0.00085
# Epoch 27/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.6269e-04 - val_loss: 8.0420e-04
#
# Epoch 00027: val_loss improved from 0.00085 to 0.00080, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.5095e-04 - val_loss: 8.5298e-04
#
# Epoch 00028: val_loss did not improve from 0.00080
# Epoch 29/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.5360e-04 - val_loss: 8.3781e-04
#
# Epoch 00029: val_loss did not improve from 0.00080
# Epoch 30/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.4437e-04 - val_loss: 8.7115e-04
#
# Epoch 00030: val_loss did not improve from 0.00080
# Epoch 31/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.3910e-04 - val_loss: 7.9848e-04
#
# Epoch 00031: val_loss improved from 0.00080 to 0.00080, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.3068e-04 - val_loss: 7.9113e-04
#
# Epoch 00032: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.2899e-04 - val_loss: 8.3728e-04
#
# Epoch 00033: val_loss did not improve from 0.00079
# Epoch 34/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.3264e-04 - val_loss: 8.8428e-04
#
# Epoch 00034: val_loss did not improve from 0.00079
# Epoch 35/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.2285e-04 - val_loss: 7.9735e-04
#
# Epoch 00035: val_loss did not improve from 0.00079
# Epoch 36/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.2206e-04 - val_loss: 8.5359e-04
#
# Epoch 00036: val_loss did not improve from 0.00079
# Epoch 37/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.1601e-04 - val_loss: 8.0272e-04
#
# Epoch 00037: val_loss did not improve from 0.00079
# Epoch 38/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.1148e-04 - val_loss: 7.8188e-04
#
# Epoch 00038: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 39/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.0930e-04 - val_loss: 8.1255e-04
#
# Epoch 00039: val_loss did not improve from 0.00078
# Epoch 40/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.0127e-04 - val_loss: 8.5905e-04
#
# Epoch 00040: val_loss did not improve from 0.00078
# Epoch 41/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9971e-04 - val_loss: 8.0402e-04
#
# Epoch 00041: val_loss did not improve from 0.00078
# Epoch 42/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9829e-04 - val_loss: 8.0468e-04
#
# Epoch 00042: val_loss did not improve from 0.00078
# Epoch 43/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9827e-04 - val_loss: 7.9278e-04
#
# Epoch 00043: val_loss did not improve from 0.00078
# Epoch 44/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9098e-04 - val_loss: 8.0112e-04
#
# Epoch 00044: val_loss did not improve from 0.00078
# Epoch 45/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.8603e-04 - val_loss: 7.9192e-04
# Epoch 00045: val_loss did not improve from 0.00078
# Epoch 46/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9056e-04 - val_loss: 7.9815e-04
#
# Epoch 00046: val_loss did not improve from 0.00078
# Epoch 47/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7951e-04 - val_loss: 8.2903e-04
#
# Epoch 00047: val_loss did not improve from 0.00078
# Epoch 48/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.8158e-04 - val_loss: 7.7825e-04
#
# Epoch 00048: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 49/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7742e-04 - val_loss: 8.2401e-04
#
# Epoch 00049: val_loss did not improve from 0.00078
# Epoch 50/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7598e-04 - val_loss: 7.8362e-04
#
# Epoch 00050: val_loss did not improve from 0.00078
# Epoch 51/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7670e-04 - val_loss: 8.5786e-04
#
# Epoch 00051: val_loss did not improve from 0.00078
# Epoch 52/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.8330e-04 - val_loss: 8.5000e-04
#
# Epoch 00052: val_loss did not improve from 0.00078
# Epoch 53/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6969e-04 - val_loss: 7.8333e-04
#
# Epoch 00053: val_loss did not improve from 0.00078
# Epoch 54/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7010e-04 - val_loss: 7.9537e-04
#
# Epoch 00054: val_loss did not improve from 0.00078
# Epoch 55/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6475e-04 - val_loss: 7.6021e-04
#
# Epoch 00055: val_loss improved from 0.00078 to 0.00076, saving model to best_weights.h5
# Epoch 56/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6497e-04 - val_loss: 7.9528e-04
#
# Epoch 00056: val_loss did not improve from 0.00076
# Epoch 57/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6059e-04 - val_loss: 7.5476e-04
#
# Epoch 00057: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 58/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6369e-04 - val_loss: 7.6286e-04
#
# Epoch 00058: val_loss did not improve from 0.00075
# Epoch 59/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6037e-04 - val_loss: 7.6143e-04
#
# Epoch 00059: val_loss did not improve from 0.00075
# Epoch 60/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5539e-04 - val_loss: 7.9493e-04
#
# Epoch 00060: val_loss did not improve from 0.00075
# Epoch 61/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5698e-04 - val_loss: 7.9316e-04
#
# Epoch 00061: val_loss did not improve from 0.00075
# Epoch 62/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5372e-04 - val_loss: 7.9298e-04
#
# Epoch 00062: val_loss did not improve from 0.00075
# Epoch 63/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5465e-04 - val_loss: 7.4408e-04
#
# Epoch 00063: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 64/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5179e-04 - val_loss: 8.0225e-04
#
# Epoch 00064: val_loss did not improve from 0.00074
# Epoch 65/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5030e-04 - val_loss: 7.5825e-04
#
# Epoch 00065: val_loss did not improve from 0.00074
# Epoch 66/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5289e-04 - val_loss: 7.8642e-04
#
# Epoch 00066: val_loss did not improve from 0.00074
# Epoch 67/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4970e-04 - val_loss: 7.7875e-04
#
# Epoch 00067: val_loss did not improve from 0.00074
# Epoch 68/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4439e-04 - val_loss: 7.7195e-04
#
# Epoch 00068: val_loss did not improve from 0.00074
# Epoch 69/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4246e-04 - val_loss: 7.9269e-04
#
# Epoch 00069: val_loss did not improve from 0.00074
# Epoch 70/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4962e-04 - val_loss: 7.9309e-04
#
# Epoch 00070: val_loss did not improve from 0.00074
# Epoch 71/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4993e-04 - val_loss: 7.7319e-04
#
# Epoch 00071: val_loss did not improve from 0.00074
# Epoch 72/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4545e-04 - val_loss: 7.7411e-04
#
# Epoch 00072: val_loss did not improve from 0.00074
# Epoch 73/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4429e-04 - val_loss: 7.9405e-04
#
# Epoch 00073: val_loss did not improve from 0.00074
# Epoch 74/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4232e-04 - val_loss: 7.5832e-04
#
# Epoch 00074: val_loss did not improve from 0.00074
# Epoch 75/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3623e-04 - val_loss: 7.5242e-04
#
# Epoch 00075: val_loss did not improve from 0.00074
# Epoch 76/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3665e-04 - val_loss: 7.9942e-04
#
# Epoch 00076: val_loss did not improve from 0.00074
# Epoch 77/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3467e-04 - val_loss: 7.4698e-04
#
# Epoch 00077: val_loss did not improve from 0.00074
# Epoch 78/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3028e-04 - val_loss: 7.5683e-04
#
# Epoch 00078: val_loss did not improve from 0.00074
# Epoch 79/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3133e-04 - val_loss: 8.1029e-04
#
# Epoch 00079: val_loss did not improve from 0.00074
# Epoch 80/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3192e-04 - val_loss: 7.9100e-04
#
# Epoch 00080: val_loss did not improve from 0.00074
# Epoch 81/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2939e-04 - val_loss: 7.8130e-04
#
# Epoch 00081: val_loss did not improve from 0.00074
# Epoch 82/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3226e-04 - val_loss: 7.6121e-04
#
# Epoch 00082: val_loss did not improve from 0.00074
# Epoch 83/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2645e-04 - val_loss: 7.9793e-04
#
# Epoch 00083: val_loss did not improve from 0.00074
# Epoch 84/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2646e-04 - val_loss: 7.6523e-04
#
# Epoch 00084: val_loss did not improve from 0.00074
# Epoch 85/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2822e-04 - val_loss: 7.8821e-04
#
# Epoch 00085: val_loss did not improve from 0.00074
# Epoch 86/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2491e-04 - val_loss: 7.7874e-04
#
# Epoch 00086: val_loss did not improve from 0.00074
# Epoch 87/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2232e-04 - val_loss: 7.5961e-04
#
# Epoch 00087: val_loss did not improve from 0.00074
# Epoch 88/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2351e-04 - val_loss: 7.8584e-04
#
# Epoch 00088: val_loss did not improve from 0.00074
# Epoch 89/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2121e-04 - val_loss: 7.9357e-04
#
# Epoch 00089: val_loss did not improve from 0.00074
# Epoch 90/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1772e-04 - val_loss: 7.6587e-04
#
# Epoch 00090: val_loss did not improve from 0.00074
# Epoch 91/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2135e-04 - val_loss: 7.8235e-04
#
# Epoch 00091: val_loss did not improve from 0.00074
# Epoch 92/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1996e-04 - val_loss: 7.9924e-04
#
# Epoch 00092: val_loss did not improve from 0.00074
# Epoch 93/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1956e-04 - val_loss: 8.1630e-04
#
# Epoch 00093: val_loss did not improve from 0.00074
# Epoch 94/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1685e-04 - val_loss: 7.6998e-04
#
# Epoch 00094: val_loss did not improve from 0.00074
# Epoch 95/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1432e-04 - val_loss: 7.4433e-04
#
# Epoch 00095: val_loss did not improve from 0.00074
# Epoch 96/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1471e-04 - val_loss: 7.5360e-04
#
# Epoch 00096: val_loss did not improve from 0.00074
# Epoch 97/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1521e-04 - val_loss: 7.7164e-04
#
# Epoch 00097: val_loss did not improve from 0.00074
# Epoch 98/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1339e-04 - val_loss: 7.7085e-04
#
# Epoch 00098: val_loss did not improve from 0.00074
# Epoch 99/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0883e-04 - val_loss: 7.6764e-04
#
# Epoch 00099: val_loss did not improve from 0.00074
# Epoch 100/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1717e-04 - val_loss: 7.7639e-04
#
# Epoch 00100: val_loss did not improve from 0.00074
# Epoch 101/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1359e-04 - val_loss: 7.6728e-04
#
# Epoch 00101: val_loss did not improve from 0.00074
# Epoch 102/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1610e-04 - val_loss: 7.8973e-04
#
# Epoch 00102: val_loss did not improve from 0.00074
# Epoch 103/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1350e-04 - val_loss: 7.6308e-04
#
# Epoch 00103: val_loss did not improve from 0.00074
# Epoch 104/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0911e-04 - val_loss: 7.7040e-04
#
# Epoch 00104: val_loss did not improve from 0.00074
# Epoch 105/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1071e-04 - val_loss: 7.6356e-04
#
# Epoch 00105: val_loss did not improve from 0.00074
# Epoch 106/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0682e-04 - val_loss: 7.4217e-04
#
# Epoch 00106: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 107/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0739e-04 - val_loss: 7.7871e-04
#
# Epoch 00107: val_loss did not improve from 0.00074
# Epoch 108/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0899e-04 - val_loss: 7.5533e-04
#
# Epoch 00108: val_loss did not improve from 0.00074
# Epoch 109/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0675e-04 - val_loss: 7.7834e-04
#
# Epoch 00109: val_loss did not improve from 0.00074
# Epoch 110/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0465e-04 - val_loss: 7.8850e-04
#
# Epoch 00110: val_loss did not improve from 0.00074
# Epoch 111/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0268e-04 - val_loss: 7.8063e-04
#
# Epoch 00111: val_loss did not improve from 0.00074
# Epoch 112/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0350e-04 - val_loss: 7.7455e-04
#
# Epoch 00112: val_loss did not improve from 0.00074
# Epoch 113/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0211e-04 - val_loss: 7.6987e-04
#
# Epoch 00113: val_loss did not improve from 0.00074
# Epoch 114/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0093e-04 - val_loss: 7.8222e-04
#
# Epoch 00114: val_loss did not improve from 0.00074
# Epoch 115/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0074e-04 - val_loss: 7.7569e-04
#
# Epoch 00115: val_loss did not improve from 0.00074
# Epoch 116/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0171e-04 - val_loss: 8.1541e-04
#
# Epoch 00116: val_loss did not improve from 0.00074
# Epoch 117/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0455e-04 - val_loss: 8.1348e-04
#
# Epoch 00117: val_loss did not improve from 0.00074
# Epoch 118/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0363e-04 - val_loss: 8.1060e-04
#
# Epoch 00118: val_loss did not improve from 0.00074
# Epoch 119/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.9486e-05 - val_loss: 7.5313e-04
#
# Epoch 00119: val_loss did not improve from 0.00074
# Epoch 120/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.9594e-05 - val_loss: 7.7633e-04
#
# Epoch 00120: val_loss did not improve from 0.00074
# Epoch 121/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.7636e-05 - val_loss: 8.0422e-04
#
# Epoch 00121: val_loss did not improve from 0.00074
# Epoch 122/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.5204e-05 - val_loss: 7.6531e-04
#
# Epoch 00122: val_loss did not improve from 0.00074
# Epoch 123/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.5038e-05 - val_loss: 7.6756e-04
#
# Epoch 00123: val_loss did not improve from 0.00074
# Epoch 124/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.5173e-05 - val_loss: 7.9918e-04
#
# Epoch 00124: val_loss did not improve from 0.00074
# Epoch 125/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.4292e-05 - val_loss: 7.8827e-04
#
# Epoch 00125: val_loss did not improve from 0.00074
# Epoch 126/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.5679e-05 - val_loss: 7.7276e-04
#
# Epoch 00126: val_loss did not improve from 0.00074
# Epoch 127/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.7019e-05 - val_loss: 7.7359e-04
#
# Epoch 00127: val_loss did not improve from 0.00074
# Epoch 128/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.3594e-05 - val_loss: 7.6020e-04
#
# Epoch 00128: val_loss did not improve from 0.00074
# Epoch 129/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.2375e-05 - val_loss: 8.0396e-04
#
# Epoch 00129: val_loss did not improve from 0.00074
# Epoch 130/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.3585e-05 - val_loss: 7.5762e-04
#
# Epoch 00130: val_loss did not improve from 0.00074
# Epoch 131/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.2710e-05 - val_loss: 7.8676e-04
#
# Epoch 00131: val_loss did not improve from 0.00074
# Epoch 132/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.9223e-05 - val_loss: 7.6786e-04
#
# Epoch 00132: val_loss did not improve from 0.00074
# Epoch 133/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.1708e-05 - val_loss: 7.8542e-04
#
# Epoch 00133: val_loss did not improve from 0.00074
# Epoch 134/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.9369e-05 - val_loss: 7.6565e-04
#
# Epoch 00134: val_loss did not improve from 0.00074
# Epoch 135/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.0109e-05 - val_loss: 7.8320e-04
#
# Epoch 00135: val_loss did not improve from 0.00074
# Epoch 136/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.0865e-05 - val_loss: 7.6347e-04
#
# Epoch 00136: val_loss did not improve from 0.00074
# Epoch 137/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.0913e-05 - val_loss: 7.9091e-04
#
# Epoch 00137: val_loss did not improve from 0.00074
# Epoch 138/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.8232e-05 - val_loss: 7.9764e-04
#
# Epoch 00138: val_loss did not improve from 0.00074
# Epoch 139/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.6591e-05 - val_loss: 7.8169e-04
#
# Epoch 00139: val_loss did not improve from 0.00074
# Epoch 140/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.0872e-05 - val_loss: 7.7477e-04
#
# Epoch 00140: val_loss did not improve from 0.00074
# Epoch 141/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.0336e-05 - val_loss: 8.1102e-04
#
# Epoch 00141: val_loss did not improve from 0.00074
# Epoch 142/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.8016e-05 - val_loss: 7.5864e-04
#
# Epoch 00142: val_loss did not improve from 0.00074
# Epoch 143/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.6333e-05 - val_loss: 7.6971e-04
#
# Epoch 00143: val_loss did not improve from 0.00074
# Epoch 144/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.4906e-05 - val_loss: 7.9753e-04
# Epoch 00144: val_loss did not improve from 0.00074
# Epoch 145/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.5118e-05 - val_loss: 7.7710e-04
#
# Epoch 00145: val_loss did not improve from 0.00074
# Epoch 146/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.6864e-05 - val_loss: 7.9375e-04
#
# Epoch 00146: val_loss did not improve from 0.00074
# Epoch 147/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.4447e-05 - val_loss: 7.8194e-04
#
# Epoch 00147: val_loss did not improve from 0.00074
# Epoch 148/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.3114e-05 - val_loss: 7.7880e-04
#
# Epoch 00148: val_loss did not improve from 0.00074
# Epoch 149/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.2907e-05 - val_loss: 7.9052e-04
#
# Epoch 00149: val_loss did not improve from 0.00074
# Epoch 150/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.2998e-05 - val_loss: 7.9867e-04
#
# Epoch 00150: val_loss did not improve from 0.00074

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
