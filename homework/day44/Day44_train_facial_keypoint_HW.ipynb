# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# C:\Users\4D212\Anaconda3\envs\dlm\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Users\4D212\Anaconda3\envs\dlm\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\4D212\Anaconda3\envs\dlm\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\4D212\Anaconda3\envs\dlm\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\4D212\Anaconda3\envs\dlm\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\4D212\Anaconda3\envs\dlm\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\4D212\Anaconda3\envs\dlm\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0061 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00214, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0016 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00214 to 0.00190, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00190 to 0.00189, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0012 - val_loss: 0.0020
#
# Epoch 00004: val_loss did not improve from 0.00189
# Epoch 5/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00189 to 0.00181, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.7624e-04 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00181 to 0.00176, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.4874e-04 - val_loss: 0.0015
#
# Epoch 00007: val_loss improved from 0.00176 to 0.00152, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 6.9914e-04 - val_loss: 0.0013
#
# Epoch 00008: val_loss improved from 0.00152 to 0.00135, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 6.1383e-04 - val_loss: 0.0012
#
# Epoch 00009: val_loss improved from 0.00135 to 0.00123, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 5.5267e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00123 to 0.00115, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 5.0473e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00115 to 0.00111, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 4.5129e-04 - val_loss: 0.0010
#
# Epoch 00012: val_loss improved from 0.00111 to 0.00101, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 4.2826e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00101 to 0.00100, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 4.0019e-04 - val_loss: 9.4560e-04
#
# Epoch 00014: val_loss improved from 0.00100 to 0.00095, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.9308e-04 - val_loss: 9.0901e-04
#
# Epoch 00015: val_loss improved from 0.00095 to 0.00091, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.6255e-04 - val_loss: 8.6928e-04
#
# Epoch 00016: val_loss improved from 0.00091 to 0.00087, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.4550e-04 - val_loss: 9.2748e-04
#
# Epoch 00017: val_loss did not improve from 0.00087
# Epoch 18/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.3185e-04 - val_loss: 8.2455e-04
#
# Epoch 00018: val_loss improved from 0.00087 to 0.00082, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.1619e-04 - val_loss: 8.3262e-04
#
# Epoch 00019: val_loss did not improve from 0.00082
# Epoch 20/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.0301e-04 - val_loss: 8.5384e-04
#
# Epoch 00020: val_loss did not improve from 0.00082
# Epoch 21/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.9245e-04 - val_loss: 8.2696e-04
#
# Epoch 00021: val_loss did not improve from 0.00082
# Epoch 22/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.7791e-04 - val_loss: 8.2540e-04
#
# Epoch 00022: val_loss did not improve from 0.00082
# Epoch 23/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.8123e-04 - val_loss: 8.3948e-04
#
# Epoch 00023: val_loss did not improve from 0.00082
# Epoch 24/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.7239e-04 - val_loss: 7.6957e-04
#
# Epoch 00024: val_loss improved from 0.00082 to 0.00077, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.6439e-04 - val_loss: 7.8873e-04
#
# Epoch 00025: val_loss did not improve from 0.00077
# Epoch 26/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.5716e-04 - val_loss: 7.6796e-04
#
# Epoch 00026: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.4551e-04 - val_loss: 7.8254e-04
#
# Epoch 00027: val_loss did not improve from 0.00077
# Epoch 28/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.4055e-04 - val_loss: 7.9160e-04
#
# Epoch 00028: val_loss did not improve from 0.00077
# Epoch 29/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.4315e-04 - val_loss: 8.3487e-04
#
# Epoch 00029: val_loss did not improve from 0.00077
# Epoch 30/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.4265e-04 - val_loss: 7.4147e-04
#
# Epoch 00030: val_loss improved from 0.00077 to 0.00074, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.2101e-04 - val_loss: 7.5364e-04
#
# Epoch 00031: val_loss did not improve from 0.00074
# Epoch 32/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.1611e-04 - val_loss: 7.5360e-04
#
# Epoch 00032: val_loss did not improve from 0.00074
# Epoch 33/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.2414e-04 - val_loss: 7.4416e-04
#
# Epoch 00033: val_loss did not improve from 0.00074
# Epoch 34/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.1578e-04 - val_loss: 7.4521e-04
#
# Epoch 00034: val_loss did not improve from 0.00074
# Epoch 35/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.1441e-04 - val_loss: 7.6345e-04
#
# Epoch 00035: val_loss did not improve from 0.00074
# Epoch 36/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.0486e-04 - val_loss: 7.4053e-04
#
# Epoch 00036: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.0153e-04 - val_loss: 7.4293e-04
#
# Epoch 00037: val_loss did not improve from 0.00074
# Epoch 38/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.0385e-04 - val_loss: 7.4504e-04
#
# Epoch 00038: val_loss did not improve from 0.00074
# Epoch 39/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9992e-04 - val_loss: 7.2028e-04
#
# Epoch 00039: val_loss improved from 0.00074 to 0.00072, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9996e-04 - val_loss: 7.4348e-04
#
# Epoch 00040: val_loss did not improve from 0.00072
# Epoch 41/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9830e-04 - val_loss: 7.3318e-04
#
# Epoch 00041: val_loss did not improve from 0.00072
# Epoch 42/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9327e-04 - val_loss: 7.2214e-04
#
# Epoch 00042: val_loss did not improve from 0.00072
# Epoch 43/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.8642e-04 - val_loss: 7.2192e-04
#
# Epoch 00043: val_loss did not improve from 0.00072
# Epoch 44/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.8074e-04 - val_loss: 7.5032e-04
#
# Epoch 00044: val_loss did not improve from 0.00072
# Epoch 45/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7976e-04 - val_loss: 6.9839e-04
#
# Epoch 00045: val_loss improved from 0.00072 to 0.00070, saving model to best_weights.h5
# Epoch 46/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7781e-04 - val_loss: 7.2671e-04
#
# Epoch 00046: val_loss did not improve from 0.00070
# Epoch 47/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7824e-04 - val_loss: 7.9505e-04
#
# Epoch 00047: val_loss did not improve from 0.00070
# Epoch 48/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.8336e-04 - val_loss: 7.7579e-04
#
# Epoch 00048: val_loss did not improve from 0.00070
# Epoch 49/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7568e-04 - val_loss: 7.3368e-04
#
# Epoch 00049: val_loss did not improve from 0.00070
# Epoch 50/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6762e-04 - val_loss: 7.0708e-04
#
# Epoch 00050: val_loss did not improve from 0.00070
# Epoch 51/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6960e-04 - val_loss: 6.9962e-04
#
# Epoch 00051: val_loss did not improve from 0.00070
# Epoch 52/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6615e-04 - val_loss: 7.2385e-04
#
# Epoch 00052: val_loss did not improve from 0.00070
# Epoch 53/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6162e-04 - val_loss: 7.0164e-04
#
# Epoch 00053: val_loss did not improve from 0.00070
# Epoch 54/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6158e-04 - val_loss: 7.1646e-04
#
# Epoch 00054: val_loss did not improve from 0.00070
# Epoch 55/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6016e-04 - val_loss: 7.4381e-04
#
# Epoch 00055: val_loss did not improve from 0.00070
# Epoch 56/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5988e-04 - val_loss: 7.7166e-04
#
# Epoch 00056: val_loss did not improve from 0.00070
# Epoch 57/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5864e-04 - val_loss: 7.2296e-04
#
# Epoch 00057: val_loss did not improve from 0.00070
# Epoch 58/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5700e-04 - val_loss: 7.0820e-04
#
# Epoch 00058: val_loss did not improve from 0.00070
# Epoch 59/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5393e-04 - val_loss: 7.2788e-04
#
# Epoch 00059: val_loss did not improve from 0.00070
# Epoch 60/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5408e-04 - val_loss: 7.0724e-04
#
# Epoch 00060: val_loss did not improve from 0.00070
# Epoch 61/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4844e-04 - val_loss: 7.1697e-04
#
# Epoch 00061: val_loss did not improve from 0.00070
# Epoch 62/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4807e-04 - val_loss: 6.9577e-04
#
# Epoch 00062: val_loss improved from 0.00070 to 0.00070, saving model to best_weights.h5
# Epoch 63/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4898e-04 - val_loss: 7.4340e-04
#
# Epoch 00063: val_loss did not improve from 0.00070
# Epoch 64/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4192e-04 - val_loss: 7.4444e-04
#
# Epoch 00064: val_loss did not improve from 0.00070
# Epoch 65/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4425e-04 - val_loss: 7.1098e-04
#
# Epoch 00065: val_loss did not improve from 0.00070
# Epoch 66/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4149e-04 - val_loss: 7.2326e-04
#
# Epoch 00066: val_loss did not improve from 0.00070
# Epoch 67/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4532e-04 - val_loss: 7.1421e-04
#
# Epoch 00067: val_loss did not improve from 0.00070
# Epoch 68/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4123e-04 - val_loss: 7.1525e-04
#
# Epoch 00068: val_loss did not improve from 0.00070
# Epoch 69/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4004e-04 - val_loss: 6.9790e-04
#
# Epoch 00069: val_loss did not improve from 0.00070
# Epoch 70/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3717e-04 - val_loss: 7.0879e-04
#
# Epoch 00070: val_loss did not improve from 0.00070
# Epoch 71/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3810e-04 - val_loss: 7.3890e-04
#
# Epoch 00071: val_loss did not improve from 0.00070
# Epoch 72/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3693e-04 - val_loss: 7.2746e-04
#
# Epoch 00072: val_loss did not improve from 0.00070
# Epoch 73/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3070e-04 - val_loss: 7.4292e-04
#
# Epoch 00073: val_loss did not improve from 0.00070
# Epoch 74/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3137e-04 - val_loss: 7.2529e-04
#
# Epoch 00074: val_loss did not improve from 0.00070
# Epoch 75/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3291e-04 - val_loss: 7.1196e-04
#
# Epoch 00075: val_loss did not improve from 0.00070
# Epoch 76/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3119e-04 - val_loss: 7.2802e-04
#
# Epoch 00076: val_loss did not improve from 0.00070
# Epoch 77/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2767e-04 - val_loss: 7.0301e-04
#
# Epoch 00077: val_loss did not improve from 0.00070
# Epoch 78/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3094e-04 - val_loss: 7.1013e-04
#
# Epoch 00078: val_loss did not improve from 0.00070
# Epoch 79/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2995e-04 - val_loss: 7.5169e-04
#
# Epoch 00079: val_loss did not improve from 0.00070
# Epoch 80/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2837e-04 - val_loss: 7.0505e-04
#
# Epoch 00080: val_loss did not improve from 0.00070
# Epoch 81/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2871e-04 - val_loss: 7.0291e-04
#
# Epoch 00081: val_loss did not improve from 0.00070
# Epoch 82/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2293e-04 - val_loss: 7.0750e-04
#
# Epoch 00082: val_loss did not improve from 0.00070
# Epoch 83/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2398e-04 - val_loss: 7.2748e-04
#
# Epoch 00083: val_loss did not improve from 0.00070
# Epoch 84/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2063e-04 - val_loss: 7.1946e-04
#
# Epoch 00084: val_loss did not improve from 0.00070
# Epoch 85/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2028e-04 - val_loss: 7.4097e-04
#
# Epoch 00085: val_loss did not improve from 0.00070
# Epoch 86/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1804e-04 - val_loss: 7.3426e-04
#
# Epoch 00086: val_loss did not improve from 0.00070
# Epoch 87/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1621e-04 - val_loss: 7.1523e-04
#
# Epoch 00087: val_loss did not improve from 0.00070
# Epoch 88/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1984e-04 - val_loss: 7.0283e-04
#
# Epoch 00088: val_loss did not improve from 0.00070
# Epoch 89/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1636e-04 - val_loss: 7.3687e-04
#
# Epoch 00089: val_loss did not improve from 0.00070
# Epoch 90/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1370e-04 - val_loss: 7.0792e-04
#
# Epoch 00090: val_loss did not improve from 0.00070
# Epoch 91/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1116e-04 - val_loss: 7.2591e-04
#
# Epoch 00091: val_loss did not improve from 0.00070
# Epoch 92/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1398e-04 - val_loss: 7.0383e-04
#
# Epoch 00092: val_loss did not improve from 0.00070
# Epoch 93/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1017e-04 - val_loss: 7.1823e-04
#
# Epoch 00093: val_loss did not improve from 0.00070
# Epoch 94/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0887e-04 - val_loss: 7.2106e-04
#
# Epoch 00094: val_loss did not improve from 0.00070
# Epoch 95/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1001e-04 - val_loss: 7.2593e-04
#
# Epoch 00095: val_loss did not improve from 0.00070
# Epoch 96/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.1364e-04 - val_loss: 6.9830e-04
#
# Epoch 00096: val_loss did not improve from 0.00070
# Epoch 97/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0904e-04 - val_loss: 7.2748e-04
#
# Epoch 00097: val_loss did not improve from 0.00070
# Epoch 98/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1438e-04 - val_loss: 7.2288e-04
#
# Epoch 00098: val_loss did not improve from 0.00070
# Epoch 99/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0946e-04 - val_loss: 6.9983e-04
#
# Epoch 00099: val_loss did not improve from 0.00070
# Epoch 100/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0941e-04 - val_loss: 7.3413e-04
#
# Epoch 00100: val_loss did not improve from 0.00070
# Epoch 101/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0764e-04 - val_loss: 7.5096e-04
#
# Epoch 00101: val_loss did not improve from 0.00070
# Epoch 102/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0677e-04 - val_loss: 6.9590e-04
#
# Epoch 00102: val_loss did not improve from 0.00070
# Epoch 103/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0576e-04 - val_loss: 7.2425e-04
#
# Epoch 00103: val_loss did not improve from 0.00070
# Epoch 104/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0276e-04 - val_loss: 7.0056e-04
#
# Epoch 00104: val_loss did not improve from 0.00070
# Epoch 105/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0260e-04 - val_loss: 6.9598e-04
#
# Epoch 00105: val_loss did not improve from 0.00070
# Epoch 106/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0254e-04 - val_loss: 7.1628e-04
#
# Epoch 00106: val_loss did not improve from 0.00070
# Epoch 107/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0017e-04 - val_loss: 7.1961e-04
#
# Epoch 00107: val_loss did not improve from 0.00070
# Epoch 108/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0113e-04 - val_loss: 7.4588e-04
#
# Epoch 00108: val_loss did not improve from 0.00070
# Epoch 109/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0254e-04 - val_loss: 7.5913e-04
#
# Epoch 00109: val_loss did not improve from 0.00070
# Epoch 110/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0018e-04 - val_loss: 7.2114e-04
#
# Epoch 00110: val_loss did not improve from 0.00070
# Epoch 111/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.9929e-05 - val_loss: 7.2617e-04
#
# Epoch 00111: val_loss did not improve from 0.00070
# Epoch 112/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.0230e-04 - val_loss: 7.1917e-04
#
# Epoch 00112: val_loss did not improve from 0.00070
# Epoch 113/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.7060e-05 - val_loss: 7.2732e-04
#
# Epoch 00113: val_loss did not improve from 0.00070
# Epoch 114/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.9704e-05 - val_loss: 7.2773e-04
#
# Epoch 00114: val_loss did not improve from 0.00070
# Epoch 115/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.6889e-05 - val_loss: 7.5058e-04
#
# Epoch 00115: val_loss did not improve from 0.00070
# Epoch 116/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.7734e-05 - val_loss: 7.4569e-04
#
# Epoch 00116: val_loss did not improve from 0.00070
# Epoch 117/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.4274e-05 - val_loss: 7.0809e-04
#
# Epoch 00117: val_loss did not improve from 0.00070
# Epoch 118/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.4899e-05 - val_loss: 7.3656e-04
#
# Epoch 00118: val_loss did not improve from 0.00070
# Epoch 119/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.8034e-05 - val_loss: 7.0089e-04
#
# Epoch 00119: val_loss did not improve from 0.00070
# Epoch 120/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.3025e-05 - val_loss: 7.4053e-04
#
# Epoch 00120: val_loss did not improve from 0.00070
# Epoch 121/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.0336e-05 - val_loss: 7.2912e-04
#
# Epoch 00121: val_loss did not improve from 0.00070
# Epoch 122/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.1254e-05 - val_loss: 7.4312e-04
#
# Epoch 00122: val_loss did not improve from 0.00070
# Epoch 123/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.2703e-05 - val_loss: 7.6352e-04
#
# Epoch 00123: val_loss did not improve from 0.00070
# Epoch 124/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.3923e-05 - val_loss: 7.4454e-04
#
# Epoch 00124: val_loss did not improve from 0.00070
# Epoch 125/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.2645e-05 - val_loss: 7.1346e-04
#
# Epoch 00125: val_loss did not improve from 0.00070
# Epoch 126/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.0379e-05 - val_loss: 7.0825e-04
#
# Epoch 00126: val_loss did not improve from 0.00070
# Epoch 127/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.7798e-05 - val_loss: 7.3490e-04
#
# Epoch 00127: val_loss did not improve from 0.00070
# Epoch 128/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.2804e-05 - val_loss: 7.3663e-04
#
# Epoch 00128: val_loss did not improve from 0.00070
# Epoch 129/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.0714e-05 - val_loss: 7.5253e-04
#
# Epoch 00129: val_loss did not improve from 0.00070
# Epoch 130/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.9865e-05 - val_loss: 7.2536e-04
#
# Epoch 00130: val_loss did not improve from 0.00070
# Epoch 131/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.6896e-05 - val_loss: 7.0541e-04
#
# Epoch 00131: val_loss did not improve from 0.00070
# Epoch 132/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.6261e-05 - val_loss: 7.0600e-04
#
# Epoch 00132: val_loss did not improve from 0.00070
# Epoch 133/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.5401e-05 - val_loss: 7.3689e-04
#
# Epoch 00133: val_loss did not improve from 0.00070
# Epoch 134/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.4837e-05 - val_loss: 7.1733e-04
#
# Epoch 00134: val_loss did not improve from 0.00070
# Epoch 135/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.6783e-05 - val_loss: 7.0984e-04
#
# Epoch 00135: val_loss did not improve from 0.00070
# Epoch 136/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.3422e-05 - val_loss: 7.3295e-04
#
# Epoch 00136: val_loss did not improve from 0.00070
# Epoch 137/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.1713e-05 - val_loss: 7.2475e-04
#
# Epoch 00137: val_loss did not improve from 0.00070
# Epoch 138/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.6008e-05 - val_loss: 7.0976e-04
#
# Epoch 00138: val_loss did not improve from 0.00070
# Epoch 139/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.6682e-05 - val_loss: 7.6034e-04
#
# Epoch 00139: val_loss did not improve from 0.00070
# Epoch 140/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.2658e-05 - val_loss: 7.1574e-04
#
# Epoch 00140: val_loss did not improve from 0.00070
# Epoch 141/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.6475e-05 - val_loss: 7.3297e-04
#
# Epoch 00141: val_loss did not improve from 0.00070
# Epoch 142/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.4837e-05 - val_loss: 7.1633e-04
#
# Epoch 00142: val_loss did not improve from 0.00070
# Epoch 143/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.3762e-05 - val_loss: 7.4484e-04
#
# Epoch 00143: val_loss did not improve from 0.00070
# Epoch 144/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.3250e-05 - val_loss: 7.4752e-04
#
# Epoch 00144: val_loss did not improve from 0.00070
# Epoch 145/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.1058e-05 - val_loss: 7.2727e-04
#
# Epoch 00145: val_loss did not improve from 0.00070
# Epoch 146/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.0731e-05 - val_loss: 7.5988e-04
#
# Epoch 00146: val_loss did not improve from 0.00070
# Epoch 147/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.2666e-05 - val_loss: 7.0823e-04
#
# Epoch 00147: val_loss did not improve from 0.00070
# Epoch 148/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 7.9827e-05 - val_loss: 7.2233e-04
#
# Epoch 00148: val_loss did not improve from 0.00070
# Epoch 149/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 7.8516e-05 - val_loss: 7.1937e-04
#
# Epoch 00149: val_loss did not improve from 0.00070
# Epoch 150/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.1007e-05 - val_loss: 7.2588e-04
#
# Epoch 00150: val_loss did not improve from 0.00070

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
def point_flip(arr):
    arr2 = arr.copy()
    #print("before")
    #print(arr2[0:5])
    for i1, v1 in enumerate(arr2):
        for i2, v2 in enumerate(v1):
            if(i2%2 ==0):
                arr2[i1,i2] = v2*-1    
                
    #print("after")            
    #print(arr2[0:5])
    return arr2
    
def image_flip(arr):
    arr2 = arr.copy()
    for i in range(96):
        arr2[:,:,i] = arr[:,:,95 - i]
        
    '''arr2 = arr.copy()
    for i1, v1 in enumerate(arr2):
        for i2 in range(48):
            arr2[i1,i2,:], arr2[i1,95-i2,:] = arr2[i1,95-i2,:], arr2[i1,i2,:]'''
    return arr2
print(points_test)
# Out:
# [[ 0.1828957  -0.11305878 -0.18904133 ...  0.1990471   0.00482644
#    0.37544367]
#  [ 0.20403856 -0.11752635 -0.21033584 ...  0.25737703  0.01511572
#    0.4072365 ]
#  [ 0.18905225 -0.11904278 -0.17504536 ...  0.24248934  0.01708217
#    0.38609308]
#  ...
#  [ 0.18392298 -0.08366022 -0.17422578 ...  0.2946131  -0.02835044
#    0.33109522]
#  [ 0.20579582 -0.1063329  -0.18600523 ...  0.2349219  -0.02930147
#    0.31423235]
#  [ 0.18152972 -0.09361851 -0.18273361 ...  0.26685938 -0.01764767
#    0.34229228]]

# %%
#print(point_flip(points_test))
points_test2 = point_flip(points_test)
imgs_test2 = image_flip(imgs_test)

fig = plt.figure(figsize=(15,15))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test2[i], np.squeeze(points_test2[i]))
